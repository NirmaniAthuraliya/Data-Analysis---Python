# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd. read_csv("instagram_global_top_1000.csv")
dataset
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
dataset
# Out:
#     Country  Rank                       Account  \
# 0       All     1                     cristiano
# 1       All     2                   kyliejenner
# 2       All     3                      leomessi
# 3       All     4                 kendalljenner
# 4       All     5                   selenagomez
# 5       All     6                       zendaya
# 6       All     7                 kimkardashian
# 7       All     8                       beyonce
# 8       All     9                  arianagrande
# 9       All    10                  billieeilish
# 10      All    11                      neymarjr
# 11      All    12                  lalalalisa_m
# 12      All    13                jennierubyjane
# 13      All    14                tomholland2013
# 14      All    15                   virat.kohli
# 15      All    16    abcdefghi__lmnopqrstuvwxyz
# 16      All    17                       khaby00
# 17      All    18               khloekardashian
# ...

# %%
dataset.shape
# Out:
# (1000, 11)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   float64
#  7   Audience Country      993 non-null    object
#  8   Authentic engagement  1000 non-null   float64
#  9   Engagement avg        1000 non-null   float64
#  10  Scraped               1000 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB

# %%
dataset.columns
# Out:
# Index(['Country', 'Rank', 'Account', 'Title', 'Link', 'Category', 'Followers',
#        'Audience Country', 'Authentic engagement', 'Engagement avg',
#        'Scraped'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#               Rank     Followers  Authentic engagement  Engagement avg
# count  1000.000000  1.000000e+03          1.000000e+03    1.000000e+03
# mean    500.500000  2.483610e+07          6.491228e+05    8.653886e+05
# std     288.819436  3.872143e+07          1.098804e+06    1.267515e+06
# min       1.000000  2.800000e+06          0.000000e+00    5.200000e+04
# 25%     250.750000  9.000000e+06          2.091000e+05    3.086000e+05
# 50%     500.500000  1.440000e+07          3.637000e+05    5.239000e+05
# 75%     750.250000  2.565000e+07          6.832500e+05    9.508000e+05
# max    1000.000000  4.696000e+08          1.340000e+07    1.340000e+07

# %%
dataset[dataset.isna().any(axis=1)]
# Out:
#     Country  Rank                     Account                           Title  \
# 15      All    16  abcdefghi__lmnopqrstuvwxyz                        Jungkook
# 16      All    17                     khaby00                      Khaby Lame
# 20      All    21                         thv                               V
# 25      All    26                         jin                      Jin of BTS
# 26      All    27                      agustd                 SUGA of BTS 민윤기
# 31      All    32                       rkive                              RM
# 33      All    34                   uarmyhope                           jhope
# 34      All    35                  badbunnypr                             NaN
# 37      All    38                 harrystyles                             NaN
# 114     All   115                  songkang_b                          송강
# 141     All   142                madelyncline                          Maddie
# ...

# %%
dataset.isna().sum()
# Out:
# Country                  0
# Rank                     0
# Account                  0
# Title                   17
# Link                     0
# Category                91
# Followers                0
# Audience Country         7
# Authentic engagement     0
# Engagement avg           0
# Scraped                  0
# dtype: int64

# %%
dataset = dataset.fillna("Unknown")

# %%
dataset[dataset.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Rank, Account, Title, Link, Category, Followers, Audience Country, Authentic engagement, Engagement avg, Scraped]
# Index: []

# %%
dataset.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# ...

# %%
dataset.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# ...

# %%
dataset = dataset.drop('Country', axis=1)

# %%
dataset.head()
# Out:
#    Rank        Account              Title  \
# 0     1      cristiano  Cristiano Ronaldo
# 1     2    kyliejenner            Kylie 🤍
# 2     3       leomessi          Leo Messi
# 3     4  kendalljenner            Kendall
# 4     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# ...

# %%
Audience_Country = dataset['Audience Country'].value_counts()
Audience_Country
# Out:
# United States           283
# Brazil                  161
# India                   143
# Indonesia               130
# Mexico                   50
# Spain                    34
# Russia                   30
# Argentina                24
# Iran                     17
# United Kingdom           17
# Turkey                   16
# Italy                    15
# South Korea              13
# Colombia                  9
# Unknown                   7
# Philippines               7
# Egypt                     6
# France                    6
# Germany                   5
# Iraq                      4
# Nigeria                   4
# Thailand                  4
# Morocco                   3
# Saudi Arabia              2
# Kazakhstan                2
# Japan                     2
# China                     1
# United Arab Emirates      1
# Poland                    1
# Algeria                   1
# Syria                     1
# Chile                     1
# Name: Audience Country, dtype: int64

# %%
dataset['Audience Country'].value_counts(normalize = True).round(3)
# Out:
# United States           0.283
# Brazil                  0.161
# India                   0.143
# Indonesia               0.130
# Mexico                  0.050
# Spain                   0.034
# Russia                  0.030
# Argentina               0.024
# Iran                    0.017
# United Kingdom          0.017
# Turkey                  0.016
# Italy                   0.015
# South Korea             0.013
# Colombia                0.009
# Unknown                 0.007
# Philippines             0.007
# Egypt                   0.006
# France                  0.006
# Germany                 0.005
# Iraq                    0.004
# Nigeria                 0.004
# Thailand                0.004
# Morocco                 0.003
# Saudi Arabia            0.002
# Kazakhstan              0.002
# Japan                   0.002
# China                   0.001
# United Arab Emirates    0.001
# Poland                  0.001
# Algeria                 0.001
# Syria                   0.001
# ...

# %%
top10AudienceCountry = Audience_Country.nlargest(10)
top10AudienceCountry
# Out:
# United States     283
# Brazil            161
# India             143
# Indonesia         130
# Mexico             50
# Spain              34
# Russia             30
# Argentina          24
# Iran               17
# United Kingdom     17
# Name: Audience Country, dtype: int64

# %%
plt.figure(figsize = (12,8))
plt.pie(top10AudienceCountry.values, labels =  top10AudienceCountry.index, autopct = '%1.2f%%')
plt.title("Top 10 Audience Countries", fontsize = 20)
plt.plot()
# Out:
# []

# %%
data_usa = dataset[dataset['Audience Country'] == 'United States']
data_usa
# Out:
#      Rank                     Account                         Title  \
# 1       2                 kyliejenner                       Kylie 🤍
# 3       4               kendalljenner                       Kendall
# 4       5                 selenagomez                  Selena Gomez
# 5       6                     zendaya                       Zendaya
# 6       7               kimkardashian           Kim Kardashian West
# 7       8                     beyonce                      Beyoncé
# 8       9                arianagrande                 Ariana Grande
# 9      10                billieeilish                 BILLIE EILISH
# 13     14              tomholland2013                   Tom Holland
# 15     16  abcdefghi__lmnopqrstuvwxyz                      Jungkook
# 17     18             khloekardashian             Khloé Kardashian
# 22     23                  badgalriri                    badgalriri
# 23     24                  nickiminaj                        Barbie
# ...

# %%
data_brazil = dataset[dataset['Audience Country'] == 'Brazil']
data_brazil
# Out:
#      Rank                       Account                           Title  \
# 10     11                      neymarjr                           NJ 🇧🇷
# 37     38                   harrystyles                         Unknown
# 55     56                   shawnmendes                    Shawn Mendes
# 56     57              milliebobbybrown              Millie Bobby Brown
# 63     64                    ursulolita              Úrsula Corberó 🐣
# 65     66                  lilireinhart                   Lili Reinhart
# 69     70              whinderssonnunes               Whindersson Nunes
# 76     77                     katyperry                      KATY PERRY
# 78     79                camila_cabello                          camila
# 79     80                     paulpogba               Paul Labile Pogba
# 98     99                      virginia          Virginia Fonseca Costa
# 99    100               jenniferaniston                Jennifer Aniston
# ...

# %%
data_ind = dataset[dataset['Audience Country'] == 'India']
data_ind
# Out:
#      Rank                   Account                           Title  \
# 0       1                 cristiano               Cristiano Ronaldo
# 14     15               virat.kohli                     Virat Kohli
# 19     20              justinbieber                   Justin Bieber
# 27     28                   therock                         therock
# 28     29                 instagram                       Instagram
# 29     30                      zayn                      Zayn Malik
# 35     36               katrinakaif                    Katrina Kaif
# 43     44             anushkasharma               AnushkaSharma1588
# 44     45              narendramodi                   Narendra Modi
# 50     51               georginagio             Georgina Rodríguez
# 54     55               akshaykumar                    Akshay Kumar
# 57     58            chrishemsworth                 Chris Hemsworth
# 59     60             oliviarodrigo                  Olivia Rodrigo
# ...

# %%
data_music = dataset[dataset['Category'] == 'Music']
data_music
# Out:
#      Rank             Account                         Title  \
# 8       9        arianagrande                 Ariana Grande
# 9      10        billieeilish                 BILLIE EILISH
# 11     12        lalalalisa_m                          LISA
# 12     13      jennierubyjane                             J
# 19     20        justinbieber                 Justin Bieber
# 21     22     roses_are_rosie                         ROSÉ
# 23     24          nickiminaj                        Barbie
# 29     30                zayn                    Zayn Malik
# 30     31       champagnepapi                 champagnepapi
# 34     35          badbunnypr                       Unknown
# 36     37               adele                         Adele
# 41     42              karolg                       KAROL G
# 46     47             dualipa                      DUA LIPA
# 49     50          mileycyrus                   Miley Cyrus
# 55     56         shawnmendes                  Shawn Mendes
# ...

# %%
data_music1 = dataset[(dataset['Category'] == 'Music') & (dataset['Followers'] >= 50000000)]
data_music1
# Out:
#      Rank             Account                     Title  \
# 8       9        arianagrande             Ariana Grande
# 9      10        billieeilish             BILLIE EILISH
# 11     12        lalalalisa_m                      LISA
# 12     13      jennierubyjane                         J
# 19     20        justinbieber             Justin Bieber
# 21     22     roses_are_rosie                     ROSÉ
# 23     24          nickiminaj                    Barbie
# 30     31       champagnepapi             champagnepapi
# 46     47             dualipa                  DUA LIPA
# 49     50          mileycyrus               Miley Cyrus
# 55     56         shawnmendes              Shawn Mendes
# 67     68            ddlovato               Demi Lovato
# 76     77           katyperry                KATY PERRY
# 78     79      camila_cabello                    camila
# 109   110          nehakakkar  Neha Kakkar (Mrs. Singh)
# 111   112  chrisbrownofficial                    BREEZY
# ...

# %%
data_cinema = dataset[dataset['Category'].str.contains('Cinema', na = False)]
data_cinema
# Out:
#      Rank                    Account                           Title  \
# 5       6                    zendaya                         Zendaya
# 13     14             tomholland2013                     Tom Holland
# 27     28                    therock                         therock
# 39     40                        jlo                  Jennifer Lopez
# 43     44              anushkasharma               AnushkaSharma1588
# 48     49             ester_exposito                         Ester 🌙
# 51     52              actorleeminho                이민호 leeminho
# 52     53                  gal_gadot                       Gal Gadot
# 54     55                akshaykumar                    Akshay Kumar
# 56     57           milliebobbybrown              Millie Bobby Brown
# 57     58             chrishemsworth                 Chris Hemsworth
# 59     60              oliviarodrigo                  Olivia Rodrigo
# 61     62          rashmika_mandanna               Rashmika Mandanna
# ...

# %%
data_fashion = data_usa[data_usa['Category'].str.contains('Fashion', na = False)]
data_fashion
# Out:
#      Rank        Account                Title  \
# 1       2    kyliejenner              Kylie 🤍
# 3       4  kendalljenner              Kendall
# 5       6        zendaya              Zendaya
# 6       7  kimkardashian  Kim Kardashian West
# 7       8        beyonce             Beyoncé
# 24     25      iamcardib              Cardi B
# 94     95     emmawatson          Emma Watson
# 361   362       demirose            Demi Rose
# 416   417          loren           loren gray
# 490   491       samsmith            Sam Smith
# 516   517           hshq      Harry Styles HQ
# 620   621         larray                larri
# 664   665    taylor_hill          Taylor Hill
# 760   761        colleen    Colleen Ballinger
# 785   786    jordynwoods          HEIR JORDYN
# 832   833   cole.labrant         Cole LaBrant
# 876   877  voguemagazine                Vogue
# 916   917     troyesivan          troye sivan
# 953   954          gucci       Gucci Official
#
# ...

# %%
data_sport = data_ind[data_ind['Category'].str.contains('Sports', na = False)]
data_sport
# Out:
#      Rank            Account                   Title  \
# 0       1          cristiano       Cristiano Ronaldo
# 14     15        virat.kohli             Virat Kohli
# 77     78       davidbeckham           David Beckham
# 140   141      rohitsharma45            Rohit Sharma
# 198   199     hardikpandya93  Hardik Himanshu Pandya
# 287   288    sachintendulkar        Sachin Tendulkar
# 353   354            rahulkl               KL Rahul👑
# 434   435           juventus                Juventus
# 573   574  indiancricketteam              Team India
# 618   619     abdevilliers17          AB de Villiers
# 661   662      davidwarner31            David Warner
# 672   673   shikhardofficial          Shikhar Dhawan
# 783   784      yuvisofficial            Yuvraj Singh
# 973   974    ravindra.jadeja     Ravindrasinh jadeja
# 986   987         rishabpant            Rishabh Pant
#
#                                              Link  \
# 0            https://www.instagram.com/cristiano/
# ...

# %%
dataset = dataset.astype({'Followers' : "float"})
dataset
# Out:
#      Rank                       Account                           Title  \
# 0       1                     cristiano               Cristiano Ronaldo
# 1       2                   kyliejenner                         Kylie 🤍
# 2       3                      leomessi                       Leo Messi
# 3       4                 kendalljenner                         Kendall
# 4       5                   selenagomez                    Selena Gomez
# 5       6                       zendaya                         Zendaya
# 6       7                 kimkardashian             Kim Kardashian West
# 7       8                       beyonce                        Beyoncé
# 8       9                  arianagrande                   Ariana Grande
# 9      10                  billieeilish                   BILLIE EILISH
# 10     11                      neymarjr                           NJ 🇧🇷
# 11     12                  lalalalisa_m                            LISA
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  1000 non-null   int64
#  1   Account               1000 non-null   object
#  2   Title                 1000 non-null   object
#  3   Link                  1000 non-null   object
#  4   Category              1000 non-null   object
#  5   Followers             1000 non-null   float64
#  6   Audience Country      1000 non-null   object
#  7   Authentic engagement  1000 non-null   float64
#  8   Engagement avg        1000 non-null   float64
#  9   Scraped               1000 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.2+ KB

# %%
top10followers = dataset.nlargest(10, 'Followers')
top10followers
# Out:
#     Rank        Account                Title  \
# 28    29      instagram            Instagram
# 0      1      cristiano    Cristiano Ronaldo
# 1      2    kyliejenner              Kylie 🤍
# 2      3       leomessi            Leo Messi
# 4      5    selenagomez         Selena Gomez
# 27    28        therock              therock
# 8      9   arianagrande        Ariana Grande
# 6      7  kimkardashian  Kim Kardashian West
# 7      8        beyonce             Beyoncé
# 19    20   justinbieber        Justin Bieber
#
#                                         Link  \
# 28      https://www.instagram.com/instagram/
# 0       https://www.instagram.com/cristiano/
# 1     https://www.instagram.com/kyliejenner/
# 2        https://www.instagram.com/leomessi/
# 4     https://www.instagram.com/selenagomez/
# 27        https://www.instagram.com/therock/
# 8    https://www.instagram.com/arianagrande/
# 6   https://www.instagram.com/kimkardashian/
# 7         https://www.instagram.com/beyonce/
# ...

# %%
plt.figure(figsize = (12,8))
plt.bar(top10followers.Category, top10followers.Followers , color = 'blue')
plt.xticks(fontsize = 12, rotation = 90)
plt.xlabel("Category", fontsize = 16)
plt.ylabel("Followers in Million", fontsize = 16)
plt.title("Top 10 Categories by followers", fontsize = 20)
plt.tight_layout()

# %%
types = dataset.Category.value_counts()
types.reset_index()
# Out:
#                                                  index  Category
# 0                                                Music       170
# 1                              Cinema|Actors/actresses       165
# 2                                   Sports with a ball       103
# 3                                              Unknown        91
# 4                                            Lifestyle        58
# 5                                             Modeling        20
# 6                                                Shows        20
# 7                        Music|Cinema|Actors/actresses        20
# 8                                  Humor|Fun|Happiness        19
# 9                                               Beauty        16
# 10                   Cinema|Actors/actresses|Lifestyle        15
# 11                                     Music|Lifestyle        10
# 12                                   Music|Art|Artists        10
# ...

# %%
top10Category = types.nlargest(10)
top10Category
# Out:
# Music                            170
# Cinema|Actors/actresses          165
# Sports with a ball               103
# Unknown                           91
# Lifestyle                         58
# Modeling                          20
# Shows                             20
# Music|Cinema|Actors/actresses     20
# Humor|Fun|Happiness               19
# Beauty                            16
# Name: Category, dtype: int64

# %%
plt.figure(figsize = (12,8))
plt.pie(top10Category.values, labels =  top10Category.index, autopct = '%1.2f%%')
plt.title("Top 10 Categories", fontsize = 20)
plt.plot()
# Out:
# []
